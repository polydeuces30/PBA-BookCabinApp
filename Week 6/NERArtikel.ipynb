# %%
import spacy

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
text = "Gubernur DKI Jakarta, Pramono Anung bakal memanggil jajaran pemerintahan serta stakeholder terkait perizinan pembangunan lapangan padel di Jakarta."
doc = nlp(text)

# %%
import spacy

# Ensure nlp and text are defined to create 'doc' if not already in scope
# This assumes 'en_core_web_sm' is the intended model and the 'text' variable from PEi0a8OP9fuo
nlp = spacy.load("en_core_web_sm")
text = "Gubernur DKI Jakarta, Pramono Anung bakal memanggil jajaran pemerintahan serta stakeholder terkait perizinan pembangunan lapangan padel di Jakarta."
doc = nlp(text)

spacy.displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Gubernur DKI
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jakarta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pramono Anung
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  bakal memanggil
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     jajaran
# ...

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

# Load IndoBERT fine-tuned for NER
model_name = "cahya/bert-base-indonesian-NER"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForTokenClassification.from_pretrained(model_name)

# Create pipeline
nlp_ner = pipeline("ner", model=model, tokenizer=tokenizer, aggregation_strategy="simple")

# Example Indonesian text
text = "Gubernur DKI Jakarta, Pramono Anung bakal memanggil jajaran pemerintahan serta stakeholder terkait perizinan pembangunan lapangan padel di Jakarta.."

# Run NER
entities = nlp_ner(text)
entities
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertForTokenClassification LOAD REPORT from: cahya/bert-base-indonesian-NER
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# bert.pooler.dense.weight     | UNEXPECTED |  |
# bert.embeddings.position_ids | UNEXPECTED |  |
# bert.pooler.dense.bias       | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [{'entity_group': 'NOR',
#   'score': np.float32(0.9928201),
#   'word': 'gubernur dki jakarta',
#   'start': 0,
#   'end': 20},
#  {'entity_group': 'PER',
#   'score': np.float32(0.9844445),
#   'word': 'pramono anung',
#   'start': 22,
#   'end': 35},
#  {'entity_group': 'NOR',
#   'score': np.float32(0.5487061),
#   'word': 'pemerintahan',
#   'start': 60,
#   'end': 72},
#  {'entity_group': 'LOC',
#   'score': np.float32(0.9515696),
#   'word': 'lapangan padel',
#   'start': 121,
# ...

# %%
from spacy import displacy

# Convert to spaCy-style
doc_data = {
    "text": text,
    "ents": [{"start": e["start"], "end": e["end"], "label": e["entity_group"]} for e in entities],
    "title": None,
}

# Visualize inline
displacy.render(doc_data, style="ent", manual=True, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gubernur DKI Jakarta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOR</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pramono Anung
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  bakal memanggil jajaran
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pemerintahan
# ...

# %%
text2 = "Pasalnya, keberadaan sejumlah lapangan padel dikeluhkan masyarakat lantaran operasionalnya mengganggu kenyamanan dan ketenangan warga."

# %%
# --- 🔐 1. Authenticate to Hugging Face ---
from huggingface_hub import login

# Paste your personal access token from https://huggingface.co/settings/tokens
# ⚠️ DO NOT share this token publicly.
login(token="YOUR_HF_TOKEN_HERE") 
login(token=hf_token)

# %%
# --- 2. Imports ---
import re, json
import spacy
from spacy import displacy
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline
from IPython.display import display, HTML

# %%
# --- 3. Load your chosen (private or public) model ---

model_name = "cahya/bert-base-indonesian-NER"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForTokenClassification.from_pretrained(model_name)
ner_pipe = pipeline("ner", model=model, tokenizer=tokenizer, aggregation_strategy="simple")
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertForTokenClassification LOAD REPORT from: cahya/bert-base-indonesian-NER
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# bert.pooler.dense.weight     | UNEXPECTED |  |
# bert.embeddings.position_ids | UNEXPECTED |  |
# bert.pooler.dense.bias       | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
print(ner_pipe("ubernur DKI Jakarta, Pramono Anung bakal memanggil jajaran pemerintahan serta stakeholder terkait perizinan pembangunan lapangan padel di Jakarta.."))
# Out:
# [{'entity_group': 'NOR', 'score': np.float32(0.84588563), 'word': 'ubernur dki jakarta', 'start': 0, 'end': 19}, {'entity_group': 'PER', 'score': np.float32(0.9821436), 'word': 'pramono anung', 'start': 21, 'end': 34}, {'entity_group': 'NOR', 'score': np.float32(0.61541533), 'word': 'pemerintahan', 'start': 59, 'end': 71}, {'entity_group': 'LOC', 'score': np.float32(0.9510165), 'word': 'lapangan padel', 'start': 120, 'end': 134}, {'entity_group': 'GPE', 'score': np.float32(0.99814594), 'word': 'jakarta', 'start': 138, 'end': 145}]

# %%
# Load your chosen (private or public) model
model_name = "cahya/bert-base-indonesian-NER"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForTokenClassification.from_pretrained(model_name)
ner_pipe = pipeline("ner", model=model, tokenizer=tokenizer, aggregation_strategy="simple")

nlp = spacy.blank("xx")

def align_entities(text, entities):
    fixed = []
    pos = 0
    for e in entities:
        word = e.get("word", "").strip()
        if not word:
            continue
        match = re.search(re.escape(word), text[pos:])
        if match:
            start = pos + match.start()
            end = pos + match.end()
            fixed.append({"start": start, "end": end, "label": e["entity_group"]})
            pos = end
    return fixed

def visualize_ner_spacy(text, show_raw=False):
    if not text.strip():
        print("Masukkan teks Bahasa Indonesia terlebih dahulu.")
        return

    entities = ner_pipe(text)
    if show_raw:
        print(json.dumps(entities, indent=2, ensure_ascii=False))

    ents_fixed = align_entities(text, entities)
    if not ents_fixed:
        print("Tidak ditemukan entitas yang bisa dipetakan ke teks.")
        return

    doc = nlp(text)
    spans = []
    for ent in ents_fixed:
        span = doc.char_span(ent["start"], ent["end"], label=ent["label"], alignment_mode="expand")
        if span:
            spans.append(span)
    doc.ents = spans

    html_out = displacy.render(doc, style="ent")
    display(HTML(html_out))
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertForTokenClassification LOAD REPORT from: cahya/bert-base-indonesian-NER
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# bert.pooler.dense.weight     | UNEXPECTED |  |
# bert.embeddings.position_ids | UNEXPECTED |  |
# bert.pooler.dense.bias       | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
text3= "Pramono ingin memastikan keberadaan lapangan olahraga tersebut sudah sesuai dengan perizinan dan regulasi yang berlaku."

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline

# Explicitly load model and tokenizer for robustness
model_name = "cahya/bert-base-indonesian-NER"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForTokenClassification.from_pretrained(model_name)

# Create pipeline
nlp_ner = pipeline("ner", model=model, tokenizer=tokenizer, aggregation_strategy="simple")

# Run NER
entities3 = nlp_ner(text3)
entities3
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertForTokenClassification LOAD REPORT from: cahya/bert-base-indonesian-NER
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# bert.pooler.dense.weight     | UNEXPECTED |  |
# bert.embeddings.position_ids | UNEXPECTED |  |
# bert.pooler.dense.bias       | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [{'entity_group': 'PER',
#   'score': np.float32(0.9657413),
#   'word': 'pramono',
#   'start': 0,
#   'end': 7}]

# %%
import spacy
from spacy import displacy
from IPython.display import display, HTML

# Re-define text3 for robustness in case previous cell was not executed
text3= "Pramono ingin memastikan keberadaan lapangan olahraga tersebut sudah sesuai dengan perizinan dan regulasi yang berlaku."

# Create blank spaCy doc (no NLP model needed)
nlp = spacy.blank("xx")

# Build doc_data manually for displaCy
doc_data = {
    "text": text3,
    "ents": [
        {"start": ent["start"], "end": ent["end"], "label": ent["entity_group"]}
        for ent in entities3
    ],
    "title": "NER Visualization"
}

# Render inside notebook
html = displacy.render(doc_data, style="ent", manual=True, jupyter=False)
display(HTML(html))
# Out:
# <h2 style="margin: 0">NER Visualization</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pramono
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  ingin memastikan keberadaan lapangan olahraga tersebut sudah sesuai dengan perizinan dan regulasi yang berlaku.</div>

# %%
text4= "Menurutnya, kenyamanan warga Jakarta menjadi prioritas utama Pemprov DKI."

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline

# Explicitly load model and tokenizer for robustness
model_name = "cahya/bert-base-indonesian-NER"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForTokenClassification.from_pretrained(model_name)

# Create pipeline
nlp_ner = pipeline("ner", model=model, tokenizer=tokenizer, aggregation_strategy="simple")

# Run NER
entities4 = nlp_ner(text4)
entities4
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertForTokenClassification LOAD REPORT from: cahya/bert-base-indonesian-NER
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# bert.pooler.dense.weight     | UNEXPECTED |  |
# bert.embeddings.position_ids | UNEXPECTED |  |
# bert.pooler.dense.bias       | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [{'entity_group': 'GPE',
#   'score': np.float32(0.9935828),
#   'word': 'jakarta',
#   'start': 29,
#   'end': 36},
#  {'entity_group': 'NOR',
#   'score': np.float32(0.98517823),
#   'word': 'pemprov dki',
#   'start': 61,
#   'end': 72}]

# %%
import spacy
from spacy import displacy
from IPython.display import display, HTML

# Re-define text4 for robustness in case previous cell was not executed
text4= "Menurutnya, kenyamanan warga Jakarta menjadi prioritas utama Pemprov DKI."

# Create blank spaCy doc (no NLP model needed)
nlp = spacy.blank("xx")

# Build doc_data manually for displaCy
doc_data = {
    "text": text4,
    "ents": [
        {"start": ent["start"], "end": ent["end"], "label": ent["entity_group"]}
        for ent in entities4
    ],
    "title": "NER Visualization"
}

# Render inside notebook
html = displacy.render(doc_data, style="ent", manual=True, jupyter=False)
display(HTML(html))
# Out:
# <h2 style="margin: 0">NER Visualization</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Menurutnya, kenyamanan warga
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jakarta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  menjadi prioritas utama
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pemprov DKI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOR</span>
# </mark>
# .</div>

# %%
text5= "Pramono menegaskan, Pemprov DKI akan mengambil tindakan tegas bagi pelaku usaha yang tidak mematuhi izin dalam menjalankan usahanya serta berdampak terhadap ketenangan masyarakat."

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline

# Explicitly load model and tokenizer for robustness
model_name = "cahya/bert-base-indonesian-NER"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForTokenClassification.from_pretrained(model_name)

# Create pipeline
nlp_ner = pipeline("ner", model=model, tokenizer=tokenizer, aggregation_strategy="simple")

# Run NER
entities5 = nlp_ner(text5)
entities5
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertForTokenClassification LOAD REPORT from: cahya/bert-base-indonesian-NER
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# bert.pooler.dense.weight     | UNEXPECTED |  |
# bert.embeddings.position_ids | UNEXPECTED |  |
# bert.pooler.dense.bias       | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [{'entity_group': 'PER',
#   'score': np.float32(0.96954054),
#   'word': 'pramono',
#   'start': 0,
#   'end': 7},
#  {'entity_group': 'NOR',
#   'score': np.float32(0.98676735),
#   'word': 'pemprov dki',
#   'start': 20,
#   'end': 31}]

# %%
import spacy
from spacy import displacy
from IPython.display import display, HTML

# Re-define text5 for robustness in case previous cell was not executed
text5= "Pramono menegaskan, Pemprov DKI akan mengambil tindakan tegas bagi pelaku usaha yang tidak mematuhi izin dalam menjalankan usahanya serta berdampak terhadap ketenangan masyarakat."

# Create blank spaCy doc (no NLP model needed)
nlp = spacy.blank("xx")

# Build doc_data manually for displaCy
doc_data = {
    "text": text5,
    "ents": [
        {"start": ent["start"], "end": ent["end"], "label": ent["entity_group"]}
        for ent in entities5
    ],
    "title": "NER Visualization"
}

# Render inside notebook
html = displacy.render(doc_data, style="ent", manual=True, jupyter=False)
display(HTML(html))
# Out:
# <h2 style="margin: 0">NER Visualization</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pramono
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  menegaskan,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pemprov DKI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOR</span>
# </mark>
#  akan mengambil tindakan tegas bagi pelaku usaha yang tidak mematuhi izin dalam menjalankan usahanya serta berdampak terhadap ketenangan masyarakat.</div>
